# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita-devel/DS_Hw2_2/blob/main/Hw2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

URL="https://drive.usercontent.google.com/download?id=1JMYqXipZpz9Y5-vyxvLEO2Y1sRBxqu-U&export=download&authuser=0"
df = pd.read_csv(URL)
assert df is not None, "DATA NOT READ FROM THE URL"

# %%
df.head(3)
# Out:
#    N           Должность Язык.программирования Специализация  \
# 0  1  Junior QA engineer                   NaN     Manual QA
# 1  2  Junior QA engineer                   NaN     Manual QA
# 2  3   Software Engineer               C#/.NET           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# 1                               130  Харьков  свыше 1000 человек  ...
# 2                               800     Киев     до 1000 человек  ...
#
#   Еще.студент Уровень.английского                    Предметная.область  \
# 0        True       ниже среднего                         iOS,eCommerce
# ...

# %%
print(df.shape)
# Out:
# (8704, 25)

# %%
print(df[df.columns].dtypes)
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# ...

# %%
df.isnull().sum()
# Out:
# N                                      0
# Должность                              0
# Язык.программирования               3850
# Специализация                       7219
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Университет                          358
# Еще.студент                            0
# Уровень.английского                    0
# Предметная.область                   223
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# ...

# %%
cols_with_null = df.isnull().sum() > 0
cols_with_null["Язык.программирования"] = False
print(cols_with_null[cols_with_null == False].index)
df = df[cols_with_null[cols_with_null == False].index]
print(df.head())
# Out:
# Index(['N', 'Должность', 'Язык.программирования', 'Общий.опыт.работы',
#        'Опыт.работы.на.текущем.месте', 'Зарплата.в.месяц',
#        'Изменение.зарплаты.за.12.месяцев', 'Город', 'Размер.компании',
#        'Тип.компании', 'Пол', 'Возраст', 'Образование', 'Еще.студент',
#        'Уровень.английского', 'Дата.заполнения', 'User.Agent', 'exp',
#        'current_job_exp', 'salary'],
#       dtype='object')
#    N                 Должность Язык.программирования Общий.опыт.работы  \
# 0  1        Junior QA engineer                   NaN               0.5
# 1  2        Junior QA engineer                   NaN  меньше 3 месяцев
# 2  3         Software Engineer               C#/.NET                 4
# 3  4         Software Engineer            JavaScript                 5
# 4  5  Senior Software Engineer            JavaScript    10 и более лет
#
#   Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0                          0.5               400
# ...

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# N                                   0
# Должность                           0
# Язык.программирования               0
# Общий.опыт.работы                   0
# Опыт.работы.на.текущем.месте        0
# Зарплата.в.месяц                    0
# Изменение.зарплаты.за.12.месяцев    0
# Город                               0
# Размер.компании                     0
# Тип.компании                        0
# Пол                                 0
# Возраст                             0
# Образование                         0
# Еще.студент                         0
# Уровень.английского                 0
# Дата.заполнения                     0
# User.Agent                          0
# exp                                 0
# current_job_exp                     0
# salary                              0
# dtype: int64

# %%
print(df.shape)
# Out:
# (4854, 20)

# %%
python_data = df[df['Язык.программирования'].str.lower() == "python"]
python_data.shape
# Out:
# (207, 20)

# %%
gr_by_posada = python_data.groupby(['Должность'])
print(gr_by_posada.count().index)
print(gr_by_posada.mean(numeric_only=True).sort_values("salary", ascending=False))
# Out:
# Index(['Junior Software Engineer', 'Senior Software Engineer',
#        'Software Engineer', 'System Architect', 'Technical Lead'],
#       dtype='object', name='Должность')
#                                     N  Зарплата.в.месяц  \
# Должность
# System Architect          6989.000000       4000.000000
# Senior Software Engineer  4781.870968       3387.096774
# Technical Lead            5370.181818       3165.909091
# Software Engineer         3668.840000       1799.070000
# Junior Software Engineer  3559.063492        560.841270
#
#                           Изменение.зарплаты.за.12.месяцев    Возраст  \
# Должность
# System Architect                                  0.000000  35.500000
# Senior Software Engineer                        431.612903  29.064516
# Technical Lead                                  455.000000  30.090909
# Software Engineer                               479.830000  26.630000
# Junior Software Engineer                        181.031746  24.174603
#
# ...

# %%
gr_by_posada['salary'] \
  .agg(['min', 'mean', 'max']) \
  .sort_values("mean", ascending=False) \
  .astype(int)
# Out:
#                            min  mean   max
# Должность
# System Architect          3000  4000  5000
# Senior Software Engineer  1300  3387  9200
# Technical Lead            1425  3165  6200
# Software Engineer          500  1799  5400
# Junior Software Engineer   100   560  1250

# %%
spec_stat = gr_by_posada['salary'].agg(['min', 'max'])
spec_stat.head()
# Out:
#                            min   max
# Должность
# Junior Software Engineer   100  1250
# Senior Software Engineer  1300  9200
# Software Engineer          500  5400
# System Architect          3000  5000
# Technical Lead            1425  6200

# %%
def fill_avg_salary(s, ref_df):
  avg = None
  try:
    sp = s.get('Должность')
    if sp:
      stat_sp = ref_df.loc[sp]
      avg=int((stat_sp["min"] + stat_sp["max"])/2)
  finally:
    s['avg']=avg
    return s


a=df.apply(fill_avg_salary, args=[spec_stat], axis=1)
a[a.columns[[0,1,2,19,20]]].head(2)
# Out:
#    N          Должность Язык.программирования  salary     avg
# 2  3  Software Engineer               C#/.NET    2500  2950.0
# 3  4  Software Engineer            JavaScript    2000  2950.0

# %%
def fill_avg(s):
  avg = None
  try:
      avg=int((s["min"] + s["max"])/2)
  finally:
    s['avg']=avg
    return s

b=spec_stat.apply(fill_avg, axis=1)
b
# Out:
#                            min   max   avg
# Должность
# Junior Software Engineer   100  1250   675
# Senior Software Engineer  1300  9200  5250
# Software Engineer          500  5400  2950
# System Architect          3000  5000  4000
# Technical Lead            1425  6200  3812

# %%
gr_by_posada['salary'] \
  .agg(['mean']).describe()
# Out:
#               mean
# count     5.000000
# mean   2582.583427
# std    1387.255829
# min     560.841270
# 25%    1799.070000
# 50%    3165.909091
# 75%    3387.096774
# max    4000.000000

# %%
print(a['avg'].describe())
print(b['avg'].describe())
# Out:
# count    4843.000000
# mean     2920.214743
# std      1612.574951
# min       675.000000
# 25%       675.000000
# 50%      2950.000000
# 75%      3812.000000
# max      5250.000000
# Name: avg, dtype: float64
# count       5.000000
# mean     3337.400000
# std      1700.056999
# min       675.000000
# 25%      2950.000000
# 50%      3812.000000
# 75%      4000.000000
# max      5250.000000
# Name: avg, dtype: float64

# %%
a.to_csv("Hw2.2a.csv")

# %%
b.to_csv("Hw2.2b.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data_url = "https://drive.usercontent.google.com/download?id=1JMYqXipZpz9Y5-vyxvLEO2Y1sRBxqu-U&export=download&authuser=0"
df = pd.read_csv(data_url)

print(df.head())

plt.figure(figsize=(12, 6))
sns.histplot(df['salary'], bins=20, kde=True, color='skyblue')
plt.title('Розподіл зарплат за місяць')
plt.xlabel('Зарплата на місяць')
plt.ylabel('Кількість спостережень')
plt.show()

plt.figure(figsize=(12, 6))
sns.countplot(y='Должность', data=df, order=df['Должность'].value_counts().index, palette='viridis')
plt.title('Кількість працівників за посадами')
plt.xlabel('Кількість працівників')
plt.ylabel('Посада')
plt.show()

plt.figure(figsize=(12, 8))
sns.boxplot(x='salary', y='Должность', data=df, palette='pastel')
plt.title('Розподіл зарплат за місяць за посадами')
plt.xlabel('Зарплата на місяць')
plt.ylabel('Посада')
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(df['Возраст'], bins=15, kde=True, color='salmon')
plt.title('Розподіл віку працівників')
plt.xlabel('Вік')
plt.ylabel('Кількість спостережень')
plt.show()

plt.figure(figsize=(8, 8))
sns.countplot(x='Уровень.английского', data=df, palette='pastel')
plt.title('Розподіл рівня англійської мови')
plt.xlabel('Рівень англійської')
plt.ylabel('Кількість працівників')
plt.show()
# Out:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# ...

# %%
print(df.columns)
# Out:
# Index(['N', 'Должность', 'Язык.программирования', 'Специализация',
#        'Общий.опыт.работы', 'Опыт.работы.на.текущем.месте', 'Зарплата.в.месяц',
#        'Изменение.зарплаты.за.12.месяцев', 'Город', 'Размер.компании',
#        'Тип.компании', 'Пол', 'Возраст', 'Образование', 'Университет',
#        'Еще.студент', 'Уровень.английского', 'Предметная.область',
#        'Дата.заполнения', 'User.Agent', 'exp', 'current_job_exp', 'salary',
#        'Валюта', 'cls'],
#       dtype='object')
